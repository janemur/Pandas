# %%
import pandas as pd
import seaborn as sns

# %%
#Install Certificates.command for macOS
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
#данные о подписке
netflix_data = pd.read_csv('https://docs.google.com/spreadsheets/d/1-cVvgPHbcqMStoUVEPkJzSk0DFqh5RG-npKckyF9q0s/export?gid=2050417244&format=csv')

# %%
netflix_data
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0       Argentina                4760             3154           1606
# 1         Austria                5640             3779           1861
# 2         Bolivia                4991             3155           1836
# 3        Bulgaria                6797             4819           1978
# 4           Chile                4994             3156           1838
# ..            ...                 ...              ...            ...
# 60        Ireland                6486             4515           1971
# 61    Switzerland                5506             3654           1852
# 62      Australia                6114             4050           2064
# 63        Denmark                4558             2978           1580
# 64  United States                5818             3826           1992
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         3.74                           6.30
# 1                         9.03                          14.67
# 2                         7.99                          10.99
# 3                         9.03                          11.29
# 4                         7.07                           9.91
# ..                         ...                            ...
# 60                        9.03                          14.67
# 61                       12.88                          20.46
# 62                        7.84                          12.12
# 63                       12.00                          15.04
# 64                        8.99                          13.99
#
#     Cost Per Month - Premium ($)
# 0                           9.26
# 1                          20.32
# 2                          13.99
# 3                          13.54
# 4                          12.74
# ..                           ...
# 60                         20.32
# 61                         26.96
# 62                         16.39
# 63                         19.60
# 64                         17.99
#
# [65 rows x 7 columns]

# %%
ppp = pd.read_csv('https://docs.google.com/spreadsheets/d/1GcaNLhEBp8N6jysbIxdUxuEqD74Kq4EmuKX7JyXRYZY/export?gid=0&format=csv')
ppp = ppp.replace('\*','',regex=True) #удаляем * из дата сета
ppp = ppp.replace('Czech Republic','Czechia',regex=True) #удаляем * из дата сета
ppp
# Out:
#                        Country           Subregion  Region      PPP    year
# 0               Liechtenstein       Western Europe  Europe    139,1  2009.0
# 1                  Luxembourg       Western Europe  Europe  114,482  2019.0
# 2                      Monaco       Western Europe  Europe    115,7  2015.0
# 3                   Singapore   South-eastern Asia    Asia   97,341  2019.0
# 4                     Ireland      Northern Europe  Europe   86,781  2019.0
# ..                         ...                 ...     ...      ...     ...
# 223                    Malawi       Eastern Africa  Africa     1,06  2019.0
# 224                  DR Congo        Middle Africa  Africa    1,098  2019.0
# 225  Central African Republic        Middle Africa  Africa      945  2019.0
# 226                   Somalia       Eastern Africa  Africa      NaN     NaN
# 227                   Burundi       Eastern Africa  Africa      752   201.0
#
# [228 rows x 5 columns]

# %%
ppp['Country'] = ppp['Country'].astype(str).str.strip() #убираем пробелы и приводим к типу строка
netflix_data['Country'] = netflix_data['Country'].astype(str) #приводим к типу строка
netflix_data['Cost Per Month - Basic ($)'] = netflix_data['Cost Per Month - Basic ($)'].astype(float) #приводим к типу флоат 
ppp['Country'] = ppp['Country'].astype(str) #Приводим к типу флоат

# %%
#Дата сет с валютами стран
currency = pd.read_csv('https://docs.google.com/spreadsheets/d/1bPihM9GfQOvvGNO6P2Hl5VwSW4QjWZzn60eBLPbyB-c/export?gid=0&format=csv')

# %%
currency
# Out:
#          Country ISO Code
# 0    Afghanistan      AFN
# 1        Albania      ALL
# 2        Algeria      DZD
# 3        Andorra      EUR
# 4         Angola      AOA
# ..           ...      ...
# 193    Venezuela      VEF
# 194      Vietnam      VND
# 195        Yemen      YER
# 196       Zambia      ZMW
# 197     Zimbabwe      USD
#
# [198 rows x 2 columns]

# %%
#СОбираем единую таблицу. Лефтджойним к данным Netflix
df = pd.merge(netflix_data, ppp, how='left', left_on='Country', right_on='Country')
df = pd.merge(df, currency, how='left', left_on='Country', right_on='Country')
df
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0       Argentina                4760             3154           1606
# 1         Austria                5640             3779           1861
# 2         Bolivia                4991             3155           1836
# 3        Bulgaria                6797             4819           1978
# 4           Chile                4994             3156           1838
# ..            ...                 ...              ...            ...
# 60        Ireland                6486             4515           1971
# 61    Switzerland                5506             3654           1852
# 62      Australia                6114             4050           2064
# 63        Denmark                4558             2978           1580
# 64  United States                5818             3826           1992
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         3.74                           6.30
# 1                         9.03                          14.67
# 2                         7.99                          10.99
# 3                         9.03                          11.29
# 4                         7.07                           9.91
# ..                         ...                            ...
# 60                        9.03                          14.67
# 61                       12.88                          20.46
# 62                        7.84                          12.12
# 63                       12.00                          15.04
# 64                        8.99                          13.99
#
#     Cost Per Month - Premium ($)               Subregion    Region     PPP  \
# 0                           9.26           South America  Americas  22,064
# 1                          20.32          Western Europe    Europe  56,188
# 2                          13.99           South America  Americas   8,724
# 3                          13.54          Eastern Europe    Europe  23,174
# 4                          12.74           South America  Americas  24,226
# ..                           ...                     ...       ...     ...
# 60                         20.32         Northern Europe    Europe  86,781
# 61                         26.96          Western Europe    Europe  68,628
# 62                         16.39  Australia, New Zealand   Oceania  49,854
# 63                         19.60         Northern Europe    Europe  57,804
# 64                         17.99        Northern America  Americas   62,53
#
#       year ISO Code
# 0   2019.0      ARS
# 1   2019.0      EUR
# 2   2019.0      BOB
# 3   2019.0      BGN
# 4   2019.0      CLP
# ..     ...      ...
# 60  2019.0      EUR
# 61  2019.0      CHF
# 62  2019.0      AUD
# 63  2019.0      DKK
# 64  2019.0      USD
#
# [65 rows x 12 columns]

# %%
#Приводим ppp к нужному формату
df = df.replace(',','.',regex=True)
pd.to_numeric(df['PPP'])
# Out:
# 0     22.064
# 1     56.188
# 2      8.724
# 3     23.174
# 4     24.226
#        ...
# 60    86.781
# 61    68.628
# 62    49.854
# 63    57.804
# 64    62.530
# Name: PPP, Length: 65, dtype: float64

# %%
#Проверяем типы переменных
df.dtypes
# Out:
# Country                           object
# Total Library Size                 int64
# No. of TV Shows                    int64
# No. of Movies                      int64
# Cost Per Month - Basic ($)       float64
# Cost Per Month - Standard ($)    float64
# Cost Per Month - Premium ($)     float64
# Subregion                         object
# Region                            object
# PPP                               object
# year                             float64
# ISO Code                          object
# dtype: object

# %% [markdown]
# #### Строим графики корреляций

# %% [markdown]
# Видим, что средний доход в стране и стоимость подписки коррелируют. При этом для базового тарифа Netflix предпочитает ставить $9

# %%
sns.regplot(x=df['Cost Per Month - Basic ($)'], y=pd.to_numeric(df['PPP']))
# Out:
# <AxesSubplot:xlabel='Cost Per Month - Basic ($)', ylabel='PPP'>

# %%
sns.regplot(x=df['Cost Per Month - Standard ($)'], y=pd.to_numeric(df['PPP']))
# Out:
# <AxesSubplot:xlabel='Cost Per Month - Standard ($)', ylabel='PPP'>

# %%
sns.regplot(x=df['Cost Per Month - Premium ($)'], y=pd.to_numeric(df['PPP']))
# Out:
# <AxesSubplot:xlabel='Cost Per Month - Premium ($)', ylabel='PPP'>

# %% [markdown]
# #### Вопрос 1: Какая средняя цена подписки, (базовой, стандартной, премиум) в зависимости от валюты страны.

# %%
df.groupby(['ISO Code']).agg({'Cost Per Month - Basic ($)': 'mean', 'Cost Per Month - Standard ($)': 'mean', 'Cost Per Month - Premium ($)': 'mean'})
# Out:
#           Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# ISO Code
# ARS                         3.740000                       6.300000
# AUD                         7.840000                      12.120000
# BGN                         9.030000                      11.290000
# BOB                         7.990000                      10.990000
# BRL                         4.610000                       7.110000
# CAD                         7.910000                      11.870000
# CHF                        12.880000                      20.460000
# CLP                         7.070000                       9.910000
# COP                         4.310000                       6.860000
# CRC                         8.990000                      12.990000
# DKK                        12.000000                      15.040000
# EUR                         9.162941                      13.543529
# GBP                         7.910000                      13.200000
# GTQ                         7.990000                      10.990000
# HNL                         7.990000                      10.990000
# HRK                         9.030000                      11.290000
# HUF                         7.640000                      10.710000
# IDR                         8.360000                      10.660000
# ILS                        10.560000                      15.050000
# INR                         2.640000                       6.610000
# ISK                         9.030000                      14.670000
# JPY                         8.730000                      13.130000
# MDL                         9.030000                      11.290000
# MXN                         6.620000                      10.430000
# MYR                         8.290000                      10.650000
# NOK                         9.940000                      12.170000
# NZD                         8.800000                      12.530000
# PEN                         6.110000                       8.560000
# PHP                         7.350000                       9.140000
# PLN                         7.130000                      10.580000
# PYG                         8.290000                      11.490000
# RON                         9.030000                      11.290000
# RUB                         8.130000                      10.840000
# SEK                        10.900000                      14.200000
# SGD                         9.510000                      12.810000
# THB                         8.340000                      10.430000
# TRY                         1.970000                       3.000000
# TWD                         9.740000                      11.900000
# UAH                         5.640000                       8.460000
# USD                         8.490000                      12.490000
# UYU                         8.990000                      12.990000
# VEF                         7.990000                      10.990000
# ZAR                         6.260000                      10.050000
#
#           Cost Per Month - Premium ($)
# ISO Code
# ARS                           9.260000
# AUD                          16.390000
# BGN                          13.540000
# BOB                          13.990000
# BRL                           9.960000
# CAD                          15.030000
# CHF                          26.960000
# CLP                          12.740000
# COP                           9.930000
# CRC                          15.990000
# DKK                          19.600000
# EUR                          17.927059
# GBP                          18.480000
# GTQ                          13.990000
# HNL                          13.990000
# HRK                          13.540000
# HUF                          13.780000
# IDR                          12.960000
# ILS                          19.540000
# INR                           8.600000
# ISK                          20.320000
# JPY                          17.450000
# MDL                          13.540000
# MXN                          14.240000
# MYR                          13.020000
# NOK                          17.750000
# NZD                          16.940000
# PEN                          11.010000
# PHP                          10.930000
# PLN                          14.760000
# PYG                          14.690000
# RON                          13.540000
# RUB                          13.560000
# SEK                          19.700000
# SGD                          16.110000
# THB                          12.520000
# TRY                           4.020000
# TWD                          14.070000
# UAH                          11.290000
# USD                          15.990000
# UYU                          15.990000
# VEF                          13.990000
# ZAR                          12.580000

# %% [markdown]
# #### Вопрос 2: Какая средняя цена подписки, (базовой, стандартной, премиум) в зависимости от континента

# %%
df.groupby(['Region']).agg({'Cost Per Month - Basic ($)': 'mean', 'Cost Per Month - Standard ($)': 'mean', 'Cost Per Month - Premium ($)': 'mean'})
# Out:
#           Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# Region
# Africa                      6.260000                      10.050000
# Americas                    7.223750                      10.465625
# Asia                        7.636667                      10.404167
# Europe                      9.230294                      13.304412
# Oceania                     8.320000                      12.325000
#
#           Cost Per Month - Premium ($)
# Region
# Africa                       12.580000
# Americas                     13.548750
# Asia                         12.966667
# Europe                       17.545588
# Oceania                      16.665000

# %% [markdown]
# #### Вопрос 3: Сколько стоит подписка относительно среднего дохода (базовая, стандартная, премиум) в Чехии?

# %%
#Доля стоимости годовой подписки на базовый тариф нетфликса относительно среднего дохода
Cz_df_1 = (df[df['Country'] == 'Czechia']['Cost Per Month - Basic ($)']*12) / (pd.to_numeric(df[df['Country'] == 'Czechia']['PPP'])*1000)

# %%
#Доля стоимости годовой подписки на стандартный тариф нетфликса относительно среднего дохода
Cz_df_2 = (df[df['Country'] == 'Czechia']['Cost Per Month - Standard ($)']*12) / (pd.to_numeric(df[df['Country'] == 'Czechia']['PPP'])*1000)

# %%
#Доля стоимости годовой подписки на премиум тариф нетфликса относительно среднего дохода
Cz_df_3 = (df[df['Country'] == 'Czechia']['Cost Per Month - Premium ($)']*12) / (pd.to_numeric(df[df['Country'] == 'Czechia']['PPP'])*1000)

# %%
Cz_df = pd.concat([Cz_df_1, Cz_df_2, Cz_df_3], ignore_index=True)
Cz_df
# Out:
# 0    0.002593
# 1    0.003374
# 2    0.004155
# dtype: float64

# %% [markdown]
# #### Вопрос 4: Какие топ-5 стран имеют самую большую доступную коллекцию сериалов?

# %%
(df.nlargest(5, 'No. of TV Shows'))['Country']
# Out:
# 8            Czechia
# 36          Slovakia
# 3           Bulgaria
# 50           Hungary
# 57    United Kingdom
# Name: Country, dtype: object

# %% [markdown]
# #### Вопрос 5: Какой процент среднего дохода россиянина будет составлять подписка Netflix?

# %%
# Процент от среднего дохода россиянина за годовую базовую Netflix подписку
(df[df['Country'] == 'Russia']['Cost Per Month - Basic ($)']*12) *100 / (pd.to_numeric(df[df['Country'] == 'Russia']['PPP'])*1000)
# Out:
# 34    0.360745
# dtype: float64

# %%
# Процент от среднего дохода россиянина за годовую стандартную Netflix подписку
(df[df['Country'] == 'Russia']['Cost Per Month - Standard ($)']*12) * 100/ (pd.to_numeric(df[df['Country'] == 'Russia']['PPP'])*1000)
# Out:
# 34    0.480994
# dtype: float64

# %%
# Процент от среднего дохода россиянина за годовую премиум Netflix подписку
(df[df['Country'] == 'Russia']['Cost Per Month - Premium ($)']*12) * 100/ (pd.to_numeric(df[df['Country'] == 'Russia']['PPP'])*1000)
# Out:
# 34    0.601686
# dtype: float64

# %% [markdown]
# #### Вопрос 6: На каком месте будет Россия, если отсортировать страны по эффективности подписки (Cost Per Title)

# %% [markdown]
# Россия будет на 17 месте

# %%
df['Cost Per Title'] = df['Cost Per Month - Standard ($)']/ df['Total Library Size']

# %%
df = df.sort_values(by='Cost Per Title')
df.reset_index(inplace = True)

# %%
df[df['Country'] == 'Russia']
# Out:
#     index Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 17     34  Russia                5711             3624           2087
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 17                        8.13                          10.84
#
#     Cost Per Month - Premium ($)       Subregion  Region     PPP    year  \
# 17                         13.56  Eastern Europe  Europe  27.044  2019.0
#
#    ISO Code  Cost Per Title
# 17      RUB        0.001898

# %% [markdown]
# #### Вопрос 7: В какой стране лучше всего брать VPN для того, чтобы платить за Netflix меньше всего?

# %% [markdown]
# Лучше всего брать в Турции

# %%
df.nsmallest(1, 'Cost Per Month - Basic ($)')
# Out:
#    index Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0     41  Turkey                4639             2930           1709
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        1.97                            3.0
#
#    Cost Per Month - Premium ($)     Subregion Region     PPP    year ISO Code  \
# 0                          4.02  Western Asia   Asia  28.424  2019.0      TRY
#
#    Cost Per Title
# 0        0.000647

# %%
df.nsmallest(1, 'Cost Per Month - Standard ($)')
# Out:
#    index Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0     41  Turkey                4639             2930           1709
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        1.97                            3.0
#
#    Cost Per Month - Premium ($)     Subregion Region     PPP    year ISO Code  \
# 0                          4.02  Western Asia   Asia  28.424  2019.0      TRY
#
#    Cost Per Title
# 0        0.000647

# %%
df.nsmallest(1, 'Cost Per Month - Premium ($)')
# Out:
#    index Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0     41  Turkey                4639             2930           1709
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        1.97                            3.0
#
#    Cost Per Month - Premium ($)     Subregion Region     PPP    year ISO Code  \
# 0                          4.02  Western Asia   Asia  28.424  2019.0      TRY
#
#    Cost Per Title
# 0        0.000647
